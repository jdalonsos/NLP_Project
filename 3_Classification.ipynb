# %%
import os
os.getcwd()
# Out:
# 'd:\\M2_MoSEF\\NLP_Project\\NLP_Project'

# %%
import pandas as pd

# %%
tweets_df_classified = pd.read_csv(
    "data/processed/stock_tweets_cleaned_capped_sentiment_responses_minimal.csv",
    encoding="utf-8-sig"
)

# %%
tweets_df_classified.head(3)
# Out:
#                         Date  \
# 0  2021-11-02 00:27:27+00:00
# 1  2022-08-18 20:34:48+00:00
# 2  2022-09-28 13:09:01+00:00
#
#                                                Tweet Stock Name Company Name  \
# 0  Sell $41,000 worth of $AAPL for 1,000 more sha...       AAPL   Apple Inc.
# 1  $AAPL CFO, Luca Maestri, filed Form 144 paperw...       AAPL   Apple Inc.
# 2  $AAPL they’re gonna say the news is fake and t...       AAPL   Apple Inc.
#
#     Date_only  longueur                                     Tweet_original  \
# 0  2021-11-02        12  Sell $41,000 worth of $AAPL for 1,000 more sha...
# 1  2022-08-18        20  $AAPL CFO, Luca Maestri, filed Form 144 paperw...
# 2  2022-09-28        15  $AAPL they’re gonna say the news is fake and t...
#
#                                          Tweet_clean sentiment  \
# 0  Sell AMOUNT_41,000 worth of TICKER_AAPL for 1,...   neutral
# 1  TICKER_AAPL CFO, Luca Maestri, filed Form 144 ...   neutral
# ...
